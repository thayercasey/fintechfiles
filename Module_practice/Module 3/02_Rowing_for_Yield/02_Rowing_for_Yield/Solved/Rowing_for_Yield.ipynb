# %% [markdown]
# # Rowing for Yield
#
# In this activity, you’ll use the Pandas `iloc` and `loc` functions to focus on areas of interest in a dataset.
#
# Instructions:
#
# 1. Import the Pandas and `pathlib` libraries.
#
# 2. Use `Path` with the `read_csv` function to read the CSV file into the DataFrame. Review the first five rows of the DataFrame to confirm the import.
#
# 3. Use the `iloc` function to select the first row of the bond yield data.
#
# 4. Use the `iloc` function to instead return the first 10 rows of data.
#
# 5. Use the `loc` function to select the full year of data for 2019. Generate summary statistics for this data by using the `describe` function.
#
# 6. Use the `loc` function to select all the data from 2020. Generate summary statistics for this data by using the `describe` function.
#
# 7. Answer the following question: How do interest rates for the two periods differ? (The two periods are 2019 and 2020&mdash;that is, before and after the economic shock to the world economy.)
#
# 8. Using the Pandas plot type of histogram (`kind='hist'`), plot the distribution of the data from 2018 onward to view the range of historical government bond yields.
#
#
# References:
#
# [Pandas iloc funtion](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html)
#
# [Pandas loc function](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html)
#
# [Pandas describe function](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html)
#
# [Pandas plot function](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html)

# %% [markdown]
# ## Step 1: Import the Pandas and `pathlib` libraries.

# %%
# Import the Pandas library
import pandas as pd


# Import the Path module from the pathlib library
from pathlib import Path

# %% [markdown]
# ## Step 2: Use `Path` with the `read_csv` function to read the CSV file into the DataFrame. Review the first five rows of the DataFrame to confirm the import.

# %%
# Read in the CSV file called "country_bond_rates.csv" using the Path module
# The CSV file is located in the Resources folder
# Set the index to the column "Date"
# Set the parse_dates and infer_datetime_format parameters
bond_rates_df = pd.read_csv(
    Path("../Resources/country_bond_rates.csv"),
    index_col='Date', 
    parse_dates=True, 
    infer_datetime_format=True
)

# Review the first 5 rows of the DataFrame
bond_rates_df.head()
# Out:
#             Mexico  Brazil  South Africa  United Kingdom   USA  Spain
# Date
# 2000-01-01   16.19   19.32         10.16          5.8227  5.33   3.80
# 2000-02-01   15.81   20.00          9.78          5.6347  5.56   3.97
# 2000-03-01   13.66   18.21          9.85          5.3707  5.72   4.10
# 2000-04-01   12.93   20.13          9.88          5.3213  5.66   4.22
# 2000-05-01   14.18   20.29         10.22          5.4033  5.92   4.68

# %% [markdown]
# ## Step 3: Use the `iloc` function to select the first row of the bond yield data.

# %%
# Use the iloc function to select the first row of the Dataframe 
bond_rates_df.iloc[0]
# Out:
# Mexico            16.1900
# Brazil            19.3200
# South Africa      10.1600
# United Kingdom     5.8227
# USA                5.3300
# Spain              3.8000
# Name: 2000-01-01 00:00:00, dtype: float64

# %% [markdown]
# ## Step 4: Use the `iloc` function to instead return the first 10 rows of data.

# %%
# Use the iloc function to select the first ten rows of the Dataframe 
bond_rates_df.iloc[0:10]
# Out:
#             Mexico  Brazil  South Africa  United Kingdom   USA  Spain
# Date
# 2000-01-01   16.19   19.32         10.16          5.8227  5.33   3.80
# 2000-02-01   15.81   20.00          9.78          5.6347  5.56   3.97
# 2000-03-01   13.66   18.21          9.85          5.3707  5.72   4.10
# 2000-04-01   12.93   20.13          9.88          5.3213  5.66   4.22
# 2000-05-01   14.18   20.29         10.22          5.4033  5.92   4.68
# 2000-06-01   50.00   50.00         50.00          5.2097  5.74   4.82
# 2000-07-01   13.73   17.80         10.23          5.2388  5.93   4.96
# 2000-08-01   15.23   17.25         10.15          5.3312  6.11   5.06
# 2000-09-01   15.06   17.22         10.16          5.3873  5.99   5.05
# 2000-10-01   15.88   17.64         10.19          5.2179  6.10   5.05

# %% [markdown]
# ## Step 5: Use the `loc` function to select the full year of data for 2019. Generate summary statistics for this data by using the `describe` function.

# %%
# Use the loc function to select data from the full year of 2019 
bond_rates_2019_df = bond_rates_df.loc['2019-01-01':'2019-12-31']

# Use the describe function to generate the summary statistics for the `bond_rates_2019_df` DataFrame
bond_rates_2019_df.describe()
# Out:
#           Mexico     Brazil  South Africa  United Kingdom        USA  \
# count  12.000000  12.000000     12.000000       12.000000  12.000000
# mean    7.843333   6.179075      7.083333        0.935825   2.071667
# std     0.315950   1.259981      0.183518        0.268235   0.333353
# min     7.120000   4.476500      6.810000        0.577600   1.540000
# 25%     7.705000   5.322675      6.997500        0.733075   1.867500
# 50%     7.940000   6.421350      7.075000        0.874900   2.150000
# 75%     8.032500   6.577925      7.140000        1.190150   2.372500
# max     8.250000   8.475400      7.510000        1.322100   2.400000
#
#            Spain
# count  12.000000
# mean   -0.411667
# std     0.079181
# min    -0.520000
# 25%    -0.480000
# 50%    -0.420000
# 75%    -0.337500
# max    -0.320000

# %% [markdown]
# ## Step 6: Use the `loc` function to select all the data from 2020. Generate summary statistics for this data by using the `describe` function.

# %%
# Use the loc function to select data from the full year of 2020 
bond_rates_2020_df = bond_rates_df.loc['2020-01-01':'2020-12-31']

# Use the describe function to generate the summary statistics for the `bond_rates_2020_df` DataFrame
bond_rates_2020_df.describe()
# Out:
#          Mexico    Brazil  South Africa  United Kingdom       USA     Spain
# count  6.000000  6.000000      6.000000        6.000000  6.000000  6.000000
# mean   6.251667  3.226067      5.440000        0.454567  0.660000 -0.313333
# std    0.851432  0.788263      1.164526        0.188286  0.688912  0.176484
# min    5.060000  2.230900      4.100000        0.274300  0.120000 -0.450000
# 25%    5.625000  2.653425      4.395000        0.297925  0.152500 -0.422500
# 50%    6.450000  3.195350      5.595000        0.409300  0.310000 -0.390000
# 75%    6.922500  3.815200      6.270000        0.589975  1.262500 -0.267500
# max    7.120000  4.240200      6.860000        0.723500  1.540000  0.010000

# %% [markdown]
# ## Step 7: Question and Answer

# %% [markdown]
# **Question**: How do interest rates for the two periods differ? (The two periods are 2019 and 2020 - that is, before and after the economic shock to the world economy.)
#
#
# **Answer**: The interest rates were much lower in 2020 than 2019. The standard deviation is also larger in 2020, indicating that rates changed more in 2020 than in 2019. All this would be indicative of Central Banks for each of these countries trying to help the struggling economies by lowering interest rates and trying to spur business and personal investment.

# %% [markdown]
# ## Step 8: Using the Pandas plot type of histogram (`kind='hist'`), plot the distribution of the data from 2018 onward to view the range of historical government bond yields.

# %%
# Plot a histogram plot(kind='hist') of the distribution of the full DataFrame 
# from 2018 onward (['2018-01-01':]) to view the range of historical government bond yields.
bond_rates_df.loc['2018-01-01':].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>
